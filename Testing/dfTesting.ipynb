# %%
# Testing pandas dataframe splitting

# %%
import pandas as pd
import re
#from pandas.io.json import json_normalize
from pandas import json_normalize
import json

# %%
# Function for splitting dataframes with concatonated values into multiple rows
# Solution provided by user: zouweilin
# Solution link: https://gist.github.com/jlln/338b4b0b55bd6984f883
# Modified to use a delimeter regex pattern, so rows can be split using different delimeters
import re
def split_dataframe_rows(df,column_selectors, delimiters):
	# we need to keep track of the ordering of the columns
	regexPattern = "|".join(map(re.escape,delimiters))
	def _split_list_to_rows(row,row_accumulator,column_selector,regexPattern):
		split_rows = {}
		max_split = 0
		for column_selector in column_selectors:
			#split_row = row[column_selector].split(regexPattern)
			split_row = re.split(regexPattern,row[column_selector])
			split_rows[column_selector] = split_row
			if len(split_row) > max_split:
				max_split = len(split_row)
			
		for i in range(max_split):
			new_row = row.to_dict()
			for column_selector in column_selectors:
				try:
					new_row[column_selector] = split_rows[column_selector].pop(0)
				except IndexError:
					new_row[column_selector] = ''
			row_accumulator.append(new_row)

	new_rows = []
	df.apply(_split_list_to_rows,axis=1,args = (new_rows,column_selectors,regexPattern))
	new_df = pd.DataFrame(new_rows, columns=df.columns)
	return new_df

# %%
json_string = '{"gatewayMessage": {"gatewayID": "949150", "gatewayName": "Ethernet Gateway 4 - 949150", "accountID": "27825", "networkID": "63001", "messageType": "0", "power": "0", "batteryLevel": "101", "date": "2020-04-28 23:06:59", "count": "22", "signalStrength": "0", "pendingChange": "False"}, "sensorMessages": [{"sensorID": "527070", "sensorName": "G11 - 527070", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "47c9d698-c756-4976-833d-698ae762fe68", "state": "0", "messageDate": "2020-04-28 23:02:27", "rawData": "47.78%2c15.4%2c4.4%2c36.6", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "47.78|15.4|4.4|36.6", "plotValues": "47.78|15.4|4.4|5.22857142857143", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "92", "pendingChange": "True", "voltage": "2.8"}, {"sensorID": "527247", "sensorName": "F09/F10 - 527247", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "1c2d9aaa-9eb2-4127-a8e2-919572263837", "state": "0", "messageDate": "2020-04-28 23:02:41", "rawData": "44.18%2c16.16%2c4%2c35.5", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "44.18|16.16|4|35.5", "plotValues": "44.18|16.16|4|5.07142857142857", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "100", "pendingChange": "True", "voltage": "2.62"}, {"sensorID": "527072", "sensorName": "G04 - 527072", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "8449130c-d11c-4429-9f6b-7bd3b798633d", "state": "0", "messageDate": "2020-04-28 23:03:33", "rawData": "47.19%2c16.67%2c5.4%2c39.2", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "47.19|16.67|5.4|39.2", "plotValues": "47.19|16.67|5.4|5.6", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "99", "pendingChange": "True", "voltage": "2.66"}, {"sensorID": "527052", "sensorName": "F12/F13 - 527052", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "b73a44c1-4c8b-4436-ad0f-b0d2c9a675c6", "state": "0", "messageDate": "2020-04-28 23:05:18", "rawData": "46.66%2c16.94%2c5.5%2c39.5", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "46.66|16.94|5.5|39.5", "plotValues": "46.66|16.94|5.5|5.64285714285714", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "95", "pendingChange": "True", "voltage": "2.7"}, {"sensorID": "527223", "sensorName": "G12/14 - 527223", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "f4fd9c23-60e1-4215-b587-e06fe09147fa", "state": "0", "messageDate": "2020-04-28 23:06:03", "rawData": "45.58%2c16.45%2c4.7%2c37.3", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue":
"dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "44.79|16.55|4.5|36.9", "plotValues": "44.79|16.55|4.5|5.27142857142857", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "95", "pendingChange": "True", "voltage": "2.61"}, {"sensorID": "527227", "sensorName": "G01 - 527227", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "6f341044-81eb-4758-8da1-de54d6e648b0", "state": "0", "messageDate": "2020-04-28 23:06:28", "rawData": "39.89%2c19.9%2c5.9%2c40.8", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "39.89|19.9|5.9|40.8", "plotValues": "39.89|19.9|5.9|5.82857142857143", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "90", "pendingChange": "True", "voltage": "2.7"}, {"sensorID": "527080", "sensorName": "B02 - 527080", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "e53e6363-2d18-4aad-89c3-fcbe319c5e39", "state": "0", "messageDate": "2020-04-28 23:06:31", "rawData": "66.01%2c13.09%2c6.9%2c43.4", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "66.01|13.09|6.9|43.4", "plotValues": "66.01|13.09|6.9|6.2", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "100", "pendingChange": "True", "voltage": "2.56"}, {"sensorID": "527081", "sensorName": "S1 - 527081", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "0baed86b-f0cb-4f14-86aa-69802ca62869", "state": "0", "messageDate": "2020-04-28 23:06:33", "rawData": "45.47%2c16.84%2c5%2c38.2", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "45.47|16.84|5|38.2", "plotValues": "45.47|16.84|5|5.45714285714286", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "77", "pendingChange": "True", "voltage": "2.8"}, {"sensorID": "527234", "sensorName": "G13 (same space as G10) - 527234", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "80ad5423-c363-4743-b338-ae5a62a577be", "state": "0", "messageDate": "2020-04-28 23:06:33", "rawData": "53.42%2c14.01%2c4.7%2c37.3", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "53.42|14.01|4.7|37.3", "plotValues": "53.42|14.01|4.7|5.32857142857143", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "100", "pendingChange": "True", "voltage": "2.59"}, {"sensorID": "527238", "sensorName": "S10 - 527238", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "a768bf94-ab41-453a-99a4-6f107d5c46d0", "state": "0", "messageDate": "2020-04-28 23:06:35", "rawData": "45.58%2c17.21%2c5.4%2c39.2", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "45.58|17.21|5.4|39.2", "plotValues": "45.58|17.21|5.4|5.6", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "92", "pendingChange": "True", "voltage": "2.64"}, {"sensorID": "527060", "sensorName": "G07 - 527060", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "4f8e9809-718c-4ca3-a9a1-2b598f92e8dc", "state": "0", "messageDate": "2020-04-28 23:06:43", "rawData": "50.74%2c14.7%2c4.6%2c37.1", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "50.74|14.7|4.6|37.1", "plotValues": "50.74|14.7|4.6|5.3", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "100", "pendingChange": "True", "voltage": "2.6"}, {"sensorID": "527076", "sensorName": "F01 - 527076", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "b81172d0-34b9-4cf7-bf5c-8da0bfbe1ff2", "state": "0", "messageDate": "2020-04-28 23:06:51", "rawData": "45.32%2c16.48%2c4.6%2c37.2", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "45.32|16.48|4.6|37.2", "plotValues": "45.32|16.48|4.6|5.31428571428571", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "96", "pendingChange": "True", "voltage": "2.74"}, {"sensorID": "527096", "sensorName": "F11 - 527096", "applicationID": "43", "networkID": "63001", "dataMessageGUID": "5b6ba2a8-2dcc-4a70-a4dd-e29fe83abd09", "state": "0", "messageDate": "2020-04-28 23:06:50", "rawData": "48.27%2c15.91%2c5%2c38.2", "dataType": "Percentage|TemperatureData|TemperatureData|MoistureWeight", "dataValue": "48.27|15.91|5|38.2", "plotValues": "48.27|15.91|5|5.45714285714286", "plotLabels": "Humidity|Celsius|DewPoint|GramsPerKilogram", "batteryLevel": "100", "signalStrength": "82", "pendingChange": "True", "voltage": "2.65"}]}'

# %%
jsonLoad = json.loads(json_string)

# %%
#Store the recieved JSON file from the request 

#with open('test.json') as json_file:
#    jsonLoad = json.load(json_file)

#gatewayMessages = jsonLoad['gatewayMessage']
sensorMessages = jsonLoad['sensorMessages']

#gatewayMessages = json_normalize(gatewayMessages)
sensorMessages = json_normalize(sensorMessages)

# %%
print(sensorMessages)
# Out:
# sensorID                        sensorName applicationID networkID  \
# 0    527070                      G11 - 527070            43     63001
# 1    527247                  F09/F10 - 527247            43     63001
# 2    527072                      G04 - 527072            43     63001
# 3    527052                  F12/F13 - 527052            43     63001
# 4    527223                   G12/14 - 527223            43     63001
# 5    527220                      G02 - 527220            43     63001
# 6    527162                      B03 - 527162            43     63001
# 7    527231                      B04 - 527231            43     63001
# 8    527291                      F04 - 527291            43     63001
# 9    527085                       S9 - 527085            43     63001
# 10   527230                       S7 - 527230            43     63001
# 11   527046                      B05 - 527046            43     63001
# ...

# %%
# Delimeters used in the recieved sensor JSON
delimeters = "%2c","|"
# The columns that need to be split to remove concatonated values
#sensorColumns = ["rawData", "dataValue", "dataType", "plotValues", "plotLabels"]
sensorColumns = ["rawData", "dataValue", "dataType", "plotValues", "plotLabels"]

splitDf = split_dataframe_rows(sensorMessages, sensorColumns, delimeters)

# %%
print(splitDf)
# Out:
# sensorID        sensorName applicationID networkID  \
# 0    527070      G11 - 527070            43     63001
# 1    527070      G11 - 527070            43     63001
# 2    527070      G11 - 527070            43     63001
# 3    527070      G11 - 527070            43     63001
# 4    527247  F09/F10 - 527247            43     63001
# ..      ...               ...           ...       ...
# 83   527076      F01 - 527076            43     63001
# 84   527096      F11 - 527096            43     63001
# 85   527096      F11 - 527096            43     63001
# 86   527096      F11 - 527096            43     63001
# 87   527096      F11 - 527096            43     63001
#
#                          dataMessageGUID state          messageDate rawData  \
# 0   47c9d698-c756-4976-833d-698ae762fe68     0  2020-04-28 23:02:27   47.78
# 1   47c9d698-c756-4976-833d-698ae762fe68     0  2020-04-28 23:02:27    15.4
# 2   47c9d698-c756-4976-833d-698ae762fe68     0  2020-04-28 23:02:27     4.4
# ...

# %%
print(splitDf.to_string())
# Out:
#        99          True    2.66
# 10   527072                      G04 - 527072            43     63001  8449130c-d11c-4429-9f6b-7bd3b798633d     0  2020-04-28 23:03:33     5.4  TemperatureData       5.4               5.4          DewPoint          100             99          True    2.66
# 11   527072                      G04 - 527072            43     63001  8449130c-d11c-4429-9f6b-7bd3b798633d     0  2020-04-28 23:03:33    39.2   MoistureWeight      39.2               5.6  GramsPerKilogram          100             99          True    2.66
# 12   527052                  F12/F13 - 527052            43     63001  b73a44c1-4c8b-4436-ad0f-b0d2c9a675c6     0  2020-04-28 23:05:18   46.66       Percentage     46.66             46.66          Humidity          100             95          True     2.7
# ...

# %%
print(splitDf["rawData"].max)
# Out:
# <bound method Series.max of 0     47.78
# 1      15.4
# 2       4.4
# 3      36.6
# 4     44.18
#       ...
# 83     37.2
# 84    48.27
# 85    15.91
# 86        5
# 87     38.2
# Name: rawData, Length: 88, dtype: object>
